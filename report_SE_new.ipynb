# %% [markdown]
# <a href="https://colab.research.google.com/github/und3f1n3d5/experiment/blob/main/report_SE_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Эксперимент**

# %% [markdown]
# ## **Цель**
#
# Проверяем гипотезу: алгоритм выделения памяти одним куском (int*)
# работает быстрее алгоритма выделения такого же куска памяти в виде отдельных
# кусков (int***)
# Испльзовали код из библиотеки M3i с различными реализациями
# конструктора. Провели исследование с целью определить,
# какой способ заполнения памяти наиболее быстр.

# %% [markdown]
# ## **Устройство**
#
# ```
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         39 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  8
#   On-line CPU(s) list:   0-7
# Vendor ID:               GenuineIntel
#   Model name:            Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz
#     CPU family:          6
#     Model:               142
#     Thread(s) per core:  2
#     Core(s) per socket:  4
#     Socket(s):           1
#     Stepping:            11
#     CPU max MHz:         4600.0000
#     CPU min MHz:         400.0000
#
# OS: Fedora 35
# ```

# %% [markdown]
# ## **Замеры : описание**
#
# Многократно измеряем время выделения памяти под M3i определенного размера.
#
# Время замеряется на тензорах размера $10^3$ , $100^3$ , $200^3$ ⋯ $1000^3$
# по 15 раз на каждый размер.
#
# ### Удельное выделение
#
# 1. Без заполнения
#
#
# 2. С заполнением 0

# %% [markdown]
# ## **Измерения**

# %%
import numpy as np
import scipy.stats as sps

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D
import ipywidgets as widgets

import typing

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid', font_scale=1.3, palette='Set2')
# %matplotlib inline

# %% [markdown]
# Чтение файлов

# %%
file0 = open("measure_0", 'r')
measure_0 = []
for line in file0:
  arr = [i for i in line.split(", ")]
  measure_0.append(arr[:-1])

file1 = open("measure_1", 'r')
measure_1 = []
for line in file1:
  arr = [i for i in line.split(", ")]
  measure_1.append(arr[:-1])

# %% [markdown]
# Без заполнения

# %%
plt.figure(figsize=(12, 10))
plt.title("rel_0 (i***)")
plt.boxplot([[int(i) for i in measure_0[0][1:]], 
            [int(i) for i in measure_0[3][1:]],
             [int(i) for i in measure_0[6][1:]],
             [int(i) for i in measure_0[9][1:]],
             [int(i) for i in measure_0[12][1:]],
             [int(i) for i in measure_0[15][1:]],
             [int(i) for i in measure_0[18][1:]],
             [int(i) for i in measure_0[21][1:]],
             [int(i) for i in measure_0[24][1:]],
             [int(i) for i in measure_0[27][1:]],
             [int(i) for i in measure_0[30][1:]]], 
            labels=[measure_0[0][0], measure_0[3][0], measure_0[6][0], measure_0[9][0], measure_0[12][0], measure_0[15][0], measure_0[18][0], measure_0[21][0],
                    measure_0[24][0], measure_0[27][0], measure_0[30][0]])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12, 10))
plt.title("rel_1 (i*)")
plt.boxplot([[int(i) for i in measure_1[0][1:]], 
            [int(i) for i in measure_1[3][1:]],
             [int(i) for i in measure_1[6][1:]],
             [int(i) for i in measure_1[9][1:]],
             [int(i) for i in measure_1[12][1:]],
             [int(i) for i in measure_1[15][1:]],
             [int(i) for i in measure_1[18][1:]],
             [int(i) for i in measure_1[21][1:]],
             [int(i) for i in measure_1[24][1:]],
             [int(i) for i in measure_1[27][1:]],
             [int(i) for i in measure_1[30][1:]]], 
            labels=[measure_1[0][0], measure_1[3][0], measure_1[6][0], measure_1[9][0], measure_1[12][0], 
                    measure_1[15][0], measure_1[18][0], measure_1[21][0],
                    measure_1[24][0], measure_1[27][0], measure_1[30][0]])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# С заполнением нулями

# %%
plt.figure(figsize=(12, 10))
plt.title("rel_0 (i***)")
plt.boxplot([[int(i) for i in measure_0[1][1:]], 
            [int(i) for i in measure_0[4][1:]],
             [int(i) for i in measure_0[7][1:]],
             [int(i) for i in measure_0[10][1:]],
             [int(i) for i in measure_0[13][1:]],
             [int(i) for i in measure_0[16][1:]],
             [int(i) for i in measure_0[19][1:]],
             [int(i) for i in measure_0[22][1:]],
             [int(i) for i in measure_0[25][1:]],
             [int(i) for i in measure_0[28][1:]],
             [int(i) for i in measure_0[31][1:]]], 
            labels=[measure_0[0][0], measure_0[3][0], measure_0[6][0], measure_0[9][0], measure_0[12][0], measure_0[15][0], measure_0[18][0], measure_0[21][0],
                    measure_0[24][0], measure_0[27][0], measure_0[30][0]])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12, 10))
plt.title("rel_1 (i*)")
plt.boxplot([[int(i) for i in measure_1[1][1:]], 
            [int(i) for i in measure_1[4][1:]],
             [int(i) for i in measure_1[7][1:]],
             [int(i) for i in measure_1[10][1:]],
             [int(i) for i in measure_1[13][1:]],
             [int(i) for i in measure_1[16][1:]],
             [int(i) for i in measure_1[19][1:]],
             [int(i) for i in measure_1[22][1:]],
             [int(i) for i in measure_1[25][1:]],
             [int(i) for i in measure_1[28][1:]],
             [int(i) for i in measure_1[31][1:]]], 
            labels=[measure_1[0][0], measure_1[3][0], measure_1[6][0], measure_1[9][0], measure_1[12][0], measure_1[15][0], measure_1[18][0], measure_1[21][0],
                    measure_1[24][0], measure_1[27][0], measure_1[30][0]])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Воспроизведение:
# * запустить run.sh (https://github.com/DanilaDanila/m3i_realizations)
# * запустить ноутбук

# %% [markdown]
# ## **Выводы**
#
# 1. Если выделять память без заполнения, то разница в скорости значительна (на
# порядки). Быстрее int*
# 2. Если выделять память с заполнением, то $O(N^3)$ заполнения доминирует над
# временем выделения памяти и разница размывается
